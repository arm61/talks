# %%
from pylj import md, sample

# %%
def sim(numb_part, temp, sampling):
    # %matplotlib notebook 
    system = md.initialise(numb_part, temp, 20, 'square')
    samp = sampling(system)
    samp.update(system)
    for i in range(5000):
        system.integrate(md.velocity_verlet) 
        system.md_sample()
        system.heat_bath(temp)
        system.step += 1
        if system.step % 25 == 0:
            samp

# %%
sim(10, 300, sample.JustCell)
# Out:
# <img src="data:image/png;base64,..." width="400">
